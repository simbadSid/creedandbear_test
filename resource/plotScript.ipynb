# %%
from matplotlib import pyplot as plt


SIZE                                    = [10, 20, 50, 100, 250, 500, 750, 1000]

executionTime_0_base                    = [5033, 11133, 25747, 51776, 133530, 251773, 375977, 523688]
executionTime_1_bufferedSave            = [297, 294, 152, 220, 38, 112]
executionTime_2_simpleSharedList        = []
executionTime_3_bufferedWriteSharedList = []

plt.grid()
plt.plot(SIZE, executionTime_0_base,                     color="red",    label="0_base")
plt.plot(SIZE, executionTime_1_bufferedSave,             color="green",  label="1_bufferedSave")
#plt.plot(SIZE, executionTime_2_simpleSharedList,        color="blue",   label="2_simpleSharedList")
#plt.plot(SIZE, executionTime_3_bufferedWriteSharedList, color="yellow", label="3_bufferedWriteSharedList")

plt.xlabel('Quantity of orders')
plt.ylabel('Total execution time (ms)')
plt.legend(loc='best')
plt.show()
